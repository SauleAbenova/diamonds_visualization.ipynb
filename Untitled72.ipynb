# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# 데이터 불러오기
url = "https://raw.githubusercontent.com/ancestor9/data/main/human_data.csv"
df = pd.read_csv(url)

print(df.head())

# 수치형 데이터만 선택
data = df[['height', 'weight', 'foot size']]
# Out:
#    Person  height  weight  foot size
# 0  female    5.71  115.83       6.90
# 1  female    5.26  103.99       6.06
# 2  female    5.46  139.57       6.91
# 3  female    5.59  130.28       7.01
# 4    male    6.14  179.61      11.83

# %%
scaler = StandardScaler()
scaled = scaler.fit_transform(data)

scaled_df = pd.DataFrame(scaled, columns=['height', 'weight', 'foot size'])
print(scaled_df.head())
# Out:
#      height    weight  foot size
# 0  0.345473 -1.597374  -1.168871
# 1 -1.401300 -2.077506  -1.573992
# 2 -0.624956 -0.634675  -1.164048
# 3 -0.120333 -1.011401  -1.115819
# 4  2.014611  0.989016   1.208804

# %%
scaled_df.hist()
plt.suptitle("Standardized Data Distribution")
plt.show()

# %%
plt.figure()
sns.boxplot(data=scaled_df)
plt.title("Boxplot of Standardized Data")
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3f183bda-243e-4a28-8be9-737141367026" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f183bda-243e-4a28-8be9-737141367026">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("human_data.csv")
print(df.head())
# Out:
#    Person  height  weight  foot size
# 0  female    5.71  115.83       6.90
# 1  female    5.26  103.99       6.06
# 2  female    5.46  139.57       6.91
# 3  female    5.59  130.28       7.01
# 4    male    6.14  179.61      11.83

# %%
plt.figure(figsize=(8,5))

plt.hist(scaled_df['height'], alpha=0.5, label='Height')
plt.hist(scaled_df['weight'], alpha=0.5, label='Weight')
plt.hist(scaled_df['foot size'], alpha=0.5, label='Foot Size')

plt.legend()
plt.title("Histograms of Three Variables (Standardized)")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,4))

# 1. height
plt.subplot(1,3,1)
plt.hist(scaled_df['height'])
plt.title("Height")

# 2. weight
plt.subplot(1,3,2)
plt.hist(scaled_df['weight'])
plt.title("Weight")

# 3. foot size
plt.subplot(1,3,3)
plt.hist(scaled_df['foot size'])
plt.title("Foot Size")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

# смещение по X
plt.hist(df['weight'], bins=15, alpha=0.6, label='Weight')
plt.hist(df['height']*30, bins=15, alpha=0.6, label='Height')  # увеличили масштаб
plt.hist(df['foot size']*50, bins=15, alpha=0.6, label='Foot Size')  # увеличили масштаб

plt.title("Histograms of Three Variables")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()

plt.show()
